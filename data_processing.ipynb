# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
df = pd.read_csv("DS/flic_button_data_export_20251110.csv")

df.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  18615183   2025-11-10 01:50:40.22+02    NaN  Aplicom A11 001        NaN
# 1  18615186  2025-11-10 01:50:42.122+02    NaN  Aplicom A11 001        NaN
# 2  18615187    2025-11-10 01:50:44.1+02    NaN  Aplicom A11 001        NaN
# 3  18615189  2025-11-10 01:50:45.963+02    NaN  Aplicom A11 001        NaN
# 4  18615192  2025-11-10 01:50:48.722+02    NaN  Aplicom A11 001        NaN
#
#         address  rssi  advdata        lat        lon  ... accx  accy  accz  \
# 0  80E4DA7EC61B   -60      NaN  60.493152  22.288016  ...  NaN   NaN   NaN
# 1  80E4DA7EC61B   -63      NaN  60.493151  22.288017  ...  NaN   NaN   NaN
# 2  80E4DA7EC61B   -76      NaN  60.493150  22.288017  ...  NaN   NaN   NaN
# 3  80E4DA7EC61B   -55      NaN  60.493148  22.288014  ...  NaN   NaN   NaN
# 4  80E4DA7EC61B   -54      NaN  60.493146  22.288012  ...  NaN   NaN   NaN
#
# ...

# %%
df.describe()
# Out:
#                  id  ruuvi  companyid         rssi          lat          lon  \
# count  6.842000e+03    0.0     6842.0  6842.000000  6842.000000  6842.000000
# mean   1.862949e+07    NaN      499.0   -87.993715    60.331300    22.797161
# std    9.218328e+03    NaN        0.0     2.613502     0.194015     0.602762
# min    1.861503e+07    NaN      499.0   -95.000000    59.819417    22.097018
# 25%    1.862030e+07    NaN      499.0   -90.000000    60.204237    22.099120
# 50%    1.863011e+07    NaN      499.0   -88.000000    60.433157    23.044344
# 75%    1.863771e+07    NaN      499.0   -87.000000    60.452013    23.350735
# max    1.864457e+07    NaN      499.0   -67.000000    60.502904    23.648723
#
#        temperature         accx         accy         accz  battvoltage  \
# count  6842.000000  6842.000000  6842.000000  6842.000000  6842.000000
# mean      7.372572   588.132710  -684.027477   -10.760012     2.600047
# ...

# %%
# load the data
df = pd.read_csv("DS/g_data_export_20251110.csv")

df.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  18615026  2025-11-10 01:48:05.187+02    NaN  Aplicom A11 001        499
# 1  18615027   2025-11-10 01:48:07.15+02    NaN  Aplicom A11 001        499
# 2  18615028  2025-11-10 01:48:09.034+02    NaN  Aplicom A11 001        499
# 3  18615033   2025-11-10 01:48:20.72+02    NaN  Aplicom A11 001        499
# 4  18615034  2025-11-10 01:48:23.017+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -86  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...
# 1  E78E9C0B06E0   -79  0201061bff9904050511ffffffff02a4fd14fff87e9655...
# 2  E198DBE2771E   -85  0201061bff9904050530ffffffff03dcfe8cfff074f668...
# 3  E78E9C0B06E0   -81  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...
# 4  E198DBE2771E   -84  0201061bff9904050530ffffffff03dcfe94ffec74f668...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...
