# %%
# Import neede libraries for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### ***Loading Data for vehicle dynamics on day 1***

# %%
# load the data
csv_path_1 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\md30_export_20251110.csv"
df1 = pd.read_csv(csv_path_1)

df1.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  43509630  2025-11-10 01:50:38.942+02  Aplicom A11 001  60.493152
# 1  43509631  2025-11-10 01:50:38.945+02  Aplicom A11 001  60.493152
# 2  43509632  2025-11-10 01:50:38.947+02  Aplicom A11 001  60.493152
# 3  43509633  2025-11-10 01:50:38.949+02  Aplicom A11 001  60.493152
# 4  43509634   2025-11-10 01:50:38.95+02  Aplicom A11 001  60.493152
#
#          lon                                            hexdata message_start  \
# 0  22.288015  0xAB 0x1 0x0 0x20 0x3 0x36 0x0 0x44 0x0 0x90 0...            ab
# 1  22.288015  0xAB 0x1 0x0 0x20 0x4 0x36 0x0 0x44 0x0 0xA3 0...            ab
# 2  22.288015  0xAB 0x1 0x0 0x20 0x5 0x36 0x0 0x44 0x0 0xB7 0...            ab
# 3  22.288015  0xAB 0x1 0x0 0x20 0x6 0x36 0x0 0x44 0x0 0xCB 0...            ab
# 4  22.288015  0xAB 0x1 0x0 0x20 0x7 0x36 0x0 0x44 0x0 0xDF 0...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %% [markdown]
# ### ***Loading Data for vehicle dynamics on day 2***

# %%
csv_path_2 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\md30_export_20251127.csv"
df2 = pd.read_csv(csv_path_2)
df2.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  47015103  2025-11-27 10:14:51.256+02  Aplicom A11 001  60.386148
# 1  47015104  2025-11-27 10:14:51.345+02  Aplicom A11 001  60.386148
# 2  47015105  2025-11-27 10:14:51.346+02  Aplicom A11 001  60.386148
# 3  47015106  2025-11-27 10:14:51.741+02  Aplicom A11 001  60.386148
# 4  47015107  2025-11-27 10:14:52.204+02  Aplicom A11 001  60.386148
#
#          lon                                            hexdata message_start  \
# 0  23.106956  0xAB 0x1 0x0 0x20 0x0 0x36 0x0 0x44 0x0 0x3F 0...            ab
# 1  23.106955  0xAB 0x1 0x0 0x20 0x1 0x36 0x0 0x44 0x0 0x53 0...            ab
# 2  23.106955  0xAB 0x1 0x0 0x20 0x2 0x36 0x0 0x44 0x0 0x66 0...            ab
# 3  23.106955  0xAB 0x1 0x0 0x20 0x3 0x36 0x0 0x44 0x0 0x7A 0...            ab
# 4  23.106954  0xAB 0x1 0x0 0x20 0x4 0x36 0x0 0x44 0x0 0x8E 0...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %% [markdown]
# ### ***Loading Data for vehicle dynamics on day 3***

# %%
csv_path_3 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\md30_export_20260109.csv"
df3 = pd.read_csv(csv_path_3)
df3.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  54179124   2026-01-09 00:00:00.02+02  Aplicom A11 001  60.378603
# 1  54179125  2026-01-09 00:00:00.524+02  Aplicom A11 001  60.378603
# 2  54179126  2026-01-09 00:00:01.021+02  Aplicom A11 001  60.378603
# 3  54179127   2026-01-09 00:00:01.52+02  Aplicom A11 001  60.378603
# 4  54179128  2026-01-09 00:00:02.021+02  Aplicom A11 001  60.378604
#
#          lon                                            hexdata message_start  \
# 0  23.594120  0xAB 0x1 0x0 0x20 0xA5 0x36 0x0 0x44 0x0 0xFC ...            ab
# 1  23.594119  0xAB 0x1 0x0 0x20 0xA6 0x36 0x0 0x44 0x0 0x10 ...            ab
# 2  23.594119  0xAB 0x1 0x0 0x20 0xA7 0x36 0x0 0x44 0x0 0x24 ...            ab
# 3  23.594119  0xAB 0x1 0x0 0x20 0xA8 0x36 0x0 0x44 0x0 0x38 ...            ab
# 4  23.594119  0xAB 0x1 0x0 0x20 0xA9 0x36 0x0 0x44 0x0 0x4B ...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %% [markdown]
# ### ***Merge 3 DF and making one called "vehicle dynamics_df"***

# %%
# Concatenate the dataframes

vehicle_dynamics_df = pd.concat(
    [df1, df2, df3],
    ignore_index=True
)

vehicle_dynamics_df.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  43509630  2025-11-10 01:50:38.942+02  Aplicom A11 001  60.493152
# 1  43509631  2025-11-10 01:50:38.945+02  Aplicom A11 001  60.493152
# 2  43509632  2025-11-10 01:50:38.947+02  Aplicom A11 001  60.493152
# 3  43509633  2025-11-10 01:50:38.949+02  Aplicom A11 001  60.493152
# 4  43509634   2025-11-10 01:50:38.95+02  Aplicom A11 001  60.493152
#
#          lon                                            hexdata message_start  \
# 0  22.288015  0xAB 0x1 0x0 0x20 0x3 0x36 0x0 0x44 0x0 0x90 0...            ab
# 1  22.288015  0xAB 0x1 0x0 0x20 0x4 0x36 0x0 0x44 0x0 0xA3 0...            ab
# 2  22.288015  0xAB 0x1 0x0 0x20 0x5 0x36 0x0 0x44 0x0 0xB7 0...            ab
# 3  22.288015  0xAB 0x1 0x0 0x20 0x6 0x36 0x0 0x44 0x0 0xCB 0...            ab
# 4  22.288015  0xAB 0x1 0x0 0x20 0x7 0x36 0x0 0x44 0x0 0xDF 0...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %% [markdown]
# ### ***Shape***

# %%
vehicle_dynamics_df.shape
# Out:
# (258260, 32)

# %% [markdown]
# ### ***Describe***

# %%
vehicle_dynamics_df.describe()
# Out:
#                  id            lat            lon  sender_id  receiver_id  \
# count  2.582600e+05  258260.000000  258260.000000   258260.0     258260.0
# mean   4.848499e+07      60.265088      22.930954        1.0          0.0
# std    5.036458e+06       0.218707       0.498394        0.0          0.0
# min    4.350963e+07      59.810994      22.097000        1.0          0.0
# 25%    4.363887e+07      60.052504      22.657507        1.0          0.0
# 50%    4.704149e+07      60.386083      23.017695        1.0          0.0
# 75%    5.426199e+07      60.442570      23.293149        1.0          0.0
# max    5.437900e+07      60.502931      23.856204        1.0          0.0
#
#        message_id  message_number  data_length  interface_version  error_code  \
# count    258260.0   258260.000000     258260.0           258260.0    258260.0
# mean         20.0      127.554856         54.0               68.0         0.0
# ...

# %% [markdown]
# ### ***Check for NaN***

# %%
vehicle_dynamics_df.isna().sum()
# Out:
# id                         0
# ts                         0
# aplicom                    0
# lat                        0
# lon                        0
# hexdata                    0
# message_start              0
# sender_id                  0
# receiver_id                0
# message_id                 0
# message_number             0
# data_length                0
# interface_version          0
# error_code                 0
# data_analyze_count         0
# data_status_warning        0
# data_status_error          0
# air_temperature            0
# relative_humidity          0
# dew_point_temperature      0
# frost_point_temperature    0
# surface_temperature        0
# surface_state              0
# en15518_surface_state      0
# grip                       0
# water_layer_thickness      0
# ice_layer_thickness        0
# snow_layer_thickness       0
# unit_status_info           0
# unit_error_bits            0
# crc                        0
# geom                       0
# ...

# %% [markdown]
# ### ***new DF***

# %%
vehicle_dynamics_df.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  43509630  2025-11-10 01:50:38.942+02  Aplicom A11 001  60.493152
# 1  43509631  2025-11-10 01:50:38.945+02  Aplicom A11 001  60.493152
# 2  43509632  2025-11-10 01:50:38.947+02  Aplicom A11 001  60.493152
# 3  43509633  2025-11-10 01:50:38.949+02  Aplicom A11 001  60.493152
# 4  43509634   2025-11-10 01:50:38.95+02  Aplicom A11 001  60.493152
#
#          lon                                            hexdata message_start  \
# 0  22.288015  0xAB 0x1 0x0 0x20 0x3 0x36 0x0 0x44 0x0 0x90 0...            ab
# 1  22.288015  0xAB 0x1 0x0 0x20 0x4 0x36 0x0 0x44 0x0 0xA3 0...            ab
# 2  22.288015  0xAB 0x1 0x0 0x20 0x5 0x36 0x0 0x44 0x0 0xB7 0...            ab
# 3  22.288015  0xAB 0x1 0x0 0x20 0x6 0x36 0x0 0x44 0x0 0xCB 0...            ab
# 4  22.288015  0xAB 0x1 0x0 0x20 0x7 0x36 0x0 0x44 0x0 0xDF 0...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %% [markdown]
# ### ***check for unique data***

# %%
vehicle_dynamics_df["aplicom"].nunique()
# Out:
# 1

# %% [markdown]
# ### ***check for Duplicates***

# %% [markdown]
# No Duplicates

# %%
vehicle_dynamics_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### ***check for DatTypes***

# %% [markdown]
# We have Numeric & String Data. On the other hand we dont have any categorical data also

# %%
pd.DataFrame(vehicle_dynamics_df.dtypes, columns=['Data Type'])
# Out:
#                         Data Type
# id                          int64
# ts                            str
# aplicom                       str
# lat                       float64
# lon                       float64
# hexdata                       str
# message_start                 str
# sender_id                   int64
# receiver_id                 int64
# message_id                  int64
# message_number              int64
# data_length                 int64
# interface_version           int64
# error_code                  int64
# data_analyze_count          int64
# data_status_warning         int64
# data_status_error           int64
# air_temperature           float64
# relative_humidity         float64
# dew_point_temperature     float64
# frost_point_temperature   float64
# surface_temperature       float64
# surface_state               int64
# en15518_surface_state       int64
# grip                      float64
# water_layer_thickness     float64
# ...
