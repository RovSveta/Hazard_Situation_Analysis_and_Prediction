# %%
# Import neede libraries for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
csv_path_1 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\flic_button_data_export_20251110.csv"
df1 = pd.read_csv(csv_path_1)

df1.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  18615183   2025-11-10 01:50:40.22+02    NaN  Aplicom A11 001        NaN
# 1  18615186  2025-11-10 01:50:42.122+02    NaN  Aplicom A11 001        NaN
# 2  18615187    2025-11-10 01:50:44.1+02    NaN  Aplicom A11 001        NaN
# 3  18615189  2025-11-10 01:50:45.963+02    NaN  Aplicom A11 001        NaN
# 4  18615192  2025-11-10 01:50:48.722+02    NaN  Aplicom A11 001        NaN
#
#         address  rssi  advdata        lat        lon  ... accx  accy  accz  \
# 0  80E4DA7EC61B   -60      NaN  60.493152  22.288016  ...  NaN   NaN   NaN
# 1  80E4DA7EC61B   -63      NaN  60.493151  22.288017  ...  NaN   NaN   NaN
# 2  80E4DA7EC61B   -76      NaN  60.493150  22.288017  ...  NaN   NaN   NaN
# 3  80E4DA7EC61B   -55      NaN  60.493148  22.288014  ...  NaN   NaN   NaN
# 4  80E4DA7EC61B   -54      NaN  60.493146  22.288012  ...  NaN   NaN   NaN
#
# ...

# %%
csv_path_2 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\flic_button_data_export_20251127.csv"
df2 = pd.read_csv(csv_path_2)
df2.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  19073454  2025-11-27 00:06:20.323+02    NaN  Aplicom A11 001        NaN
# 1  19073455  2025-11-27 00:06:21.841+02    NaN  Aplicom A11 001        NaN
# 2  19073456  2025-11-27 00:06:23.638+02    NaN  Aplicom A11 001        NaN
# 3  19073457  2025-11-27 00:06:25.228+02    NaN  Aplicom A11 001        NaN
# 4  19073458  2025-11-27 00:06:26.774+02    NaN  Aplicom A11 001        NaN
#
#         address  rssi  advdata        lat        lon  ... accx  accy  accz  \
# 0  80E4DA7EC61B   -65      NaN  60.234862  23.588156  ...  NaN   NaN   NaN
# 1  80E4DA7EC61B   -58      NaN  60.235090  23.587418  ...  NaN   NaN   NaN
# 2  80E4DA7EC61B   -51      NaN  60.235293  23.586860  ...  NaN   NaN   NaN
# 3  80E4DA7EC61B   -65      NaN  60.235455  23.586463  ...  NaN   NaN   NaN
# 4  80E4DA7EC61B   -78  20106.0  60.235624  23.586074  ...  NaN   NaN   NaN
#
# ...

# %%
csv_path_3 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\flic_button_data_export_20260109.csv"
df3 = pd.read_csv(csv_path_3)
df3.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  20045549  2026-01-09 01:16:43.519+02    NaN  Aplicom A11 001        NaN
# 1  20045550  2026-01-09 01:16:45.393+02    NaN  Aplicom A11 001        NaN
# 2  20045551  2026-01-09 01:16:47.808+02    NaN  Aplicom A11 001        NaN
# 3  20045552  2026-01-09 01:16:50.341+02    NaN  Aplicom A11 001        NaN
# 4  20045553  2026-01-09 01:16:52.207+02    NaN  Aplicom A11 001        NaN
#
#         address  rssi  advdata        lat        lon  ... accx  accy  accz  \
# 0  80E4DA7EC61B   -70      NaN  60.463376  22.109561  ...  NaN   NaN   NaN
# 1  80E4DA7EC61B   -59  20106.0  60.463308  22.109523  ...  NaN   NaN   NaN
# 2  80E4DA7EC61B   -66      NaN  60.463243  22.109489  ...  NaN   NaN   NaN
# 3  80E4DA7EC61B   -63      NaN  60.463080  22.109335  ...  NaN   NaN   NaN
# 4  80E4DA7EC61B   -61      NaN  60.462975  22.109186  ...  NaN   NaN   NaN
#
# ...

# %%
csv_path_4 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\g_data_export_20251110.csv"
df4 = pd.read_csv(csv_path_4)
df4.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  18615026  2025-11-10 01:48:05.187+02    NaN  Aplicom A11 001        499
# 1  18615027   2025-11-10 01:48:07.15+02    NaN  Aplicom A11 001        499
# 2  18615028  2025-11-10 01:48:09.034+02    NaN  Aplicom A11 001        499
# 3  18615033   2025-11-10 01:48:20.72+02    NaN  Aplicom A11 001        499
# 4  18615034  2025-11-10 01:48:23.017+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -86  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...
# 1  E78E9C0B06E0   -79  0201061bff9904050511ffffffff02a4fd14fff87e9655...
# 2  E198DBE2771E   -85  0201061bff9904050530ffffffff03dcfe8cfff074f668...
# 3  E78E9C0B06E0   -81  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...
# 4  E198DBE2771E   -84  0201061bff9904050530ffffffff03dcfe94ffec74f668...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %%
csv_path_5 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\g_data_export_20251127.csv"
df5 = pd.read_csv(csv_path_5)
df5.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  19073449  2025-11-27 00:00:05.695+02    NaN  Aplicom A11 001        499
# 1  19073450  2025-11-27 00:02:15.075+02    NaN  Aplicom A11 001        499
# 2  19073451  2025-11-27 00:03:18.962+02    NaN  Aplicom A11 001        499
# 3  19073452   2025-11-27 00:05:26.44+02    NaN  Aplicom A11 001        499
# 4  19073453  2025-11-27 00:06:14.015+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -87  0201061bff990405fbd6ffffffff0274fd18003470f6f6...
# 1  E78E9C0B06E0   -89  0201061bff990405fbcfffffffff022cfd7c00047176e6...
# 2  E78E9C0B06E0   -93  0201061bff990405fbeeffffffff0290fdbcffac71d649...
# 3  E78E9C0B06E0   -89  0201061bff990405fbefffffffff02acfcb4ffd87176f9...
# 4  E78E9C0B06E0   -90  0201061bff990405fbfaffffffff025cfd10fffc70163a...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %%
csv_path_6 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\g_data_export_20260109.csv"
df6 = pd.read_csv(csv_path_6)
df6.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  20043979  2026-01-09 00:06:10.854+02    NaN  Aplicom A11 001        499
# 1  20043980  2026-01-09 00:06:57.334+02    NaN  Aplicom A11 001        499
# 2  20043981  2026-01-09 00:06:58.861+02    NaN  Aplicom A11 001        499
# 3  20043982  2026-01-09 00:08:24.204+02    NaN  Aplicom A11 001        499
# 4  20044343    2026-01-09 00:09:21.9+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -87  0201061bff990405f37affffffff02c4fd2000086136de...
# 1  E78E9C0B06E0   -89  0201061bff990405f37affffffff02dcfcc0ffc45d362c...
# 2  E78E9C0B06E0   -89  0201061bff990405f378ffffffff02acfd08ffac5d3632...
# 3  E78E9C0B06E0   -88  0201061bff990405f37affffffff02b0fd8c00105f76d7...
# 4  E78E9C0B06E0   -89  0201061bff990405f377ffffffff0260fcb0ffa45d9641...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %%
csv_path_7 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\md30_export_20251110.csv"
df7 = pd.read_csv(csv_path_7)
df7.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  43509630  2025-11-10 01:50:38.942+02  Aplicom A11 001  60.493152
# 1  43509631  2025-11-10 01:50:38.945+02  Aplicom A11 001  60.493152
# 2  43509632  2025-11-10 01:50:38.947+02  Aplicom A11 001  60.493152
# 3  43509633  2025-11-10 01:50:38.949+02  Aplicom A11 001  60.493152
# 4  43509634   2025-11-10 01:50:38.95+02  Aplicom A11 001  60.493152
#
#          lon                                            hexdata message_start  \
# 0  22.288015  0xAB 0x1 0x0 0x20 0x3 0x36 0x0 0x44 0x0 0x90 0...            ab
# 1  22.288015  0xAB 0x1 0x0 0x20 0x4 0x36 0x0 0x44 0x0 0xA3 0...            ab
# 2  22.288015  0xAB 0x1 0x0 0x20 0x5 0x36 0x0 0x44 0x0 0xB7 0...            ab
# 3  22.288015  0xAB 0x1 0x0 0x20 0x6 0x36 0x0 0x44 0x0 0xCB 0...            ab
# 4  22.288015  0xAB 0x1 0x0 0x20 0x7 0x36 0x0 0x44 0x0 0xDF 0...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %%
csv_path_8 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\md30_export_20251127.csv"
df8 = pd.read_csv(csv_path_8)
df8.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  47015103  2025-11-27 10:14:51.256+02  Aplicom A11 001  60.386148
# 1  47015104  2025-11-27 10:14:51.345+02  Aplicom A11 001  60.386148
# 2  47015105  2025-11-27 10:14:51.346+02  Aplicom A11 001  60.386148
# 3  47015106  2025-11-27 10:14:51.741+02  Aplicom A11 001  60.386148
# 4  47015107  2025-11-27 10:14:52.204+02  Aplicom A11 001  60.386148
#
#          lon                                            hexdata message_start  \
# 0  23.106956  0xAB 0x1 0x0 0x20 0x0 0x36 0x0 0x44 0x0 0x3F 0...            ab
# 1  23.106955  0xAB 0x1 0x0 0x20 0x1 0x36 0x0 0x44 0x0 0x53 0...            ab
# 2  23.106955  0xAB 0x1 0x0 0x20 0x2 0x36 0x0 0x44 0x0 0x66 0...            ab
# 3  23.106955  0xAB 0x1 0x0 0x20 0x3 0x36 0x0 0x44 0x0 0x7A 0...            ab
# 4  23.106954  0xAB 0x1 0x0 0x20 0x4 0x36 0x0 0x44 0x0 0x8E 0...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...

# %%
csv_path_9 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\md30_export_20260109.csv"
df9 = pd.read_csv(csv_path_9)
df9.head()
# Out:
#          id                          ts          aplicom        lat  \
# 0  54179124   2026-01-09 00:00:00.02+02  Aplicom A11 001  60.378603
# 1  54179125  2026-01-09 00:00:00.524+02  Aplicom A11 001  60.378603
# 2  54179126  2026-01-09 00:00:01.021+02  Aplicom A11 001  60.378603
# 3  54179127   2026-01-09 00:00:01.52+02  Aplicom A11 001  60.378603
# 4  54179128  2026-01-09 00:00:02.021+02  Aplicom A11 001  60.378604
#
#          lon                                            hexdata message_start  \
# 0  23.594120  0xAB 0x1 0x0 0x20 0xA5 0x36 0x0 0x44 0x0 0xFC ...            ab
# 1  23.594119  0xAB 0x1 0x0 0x20 0xA6 0x36 0x0 0x44 0x0 0x10 ...            ab
# 2  23.594119  0xAB 0x1 0x0 0x20 0xA7 0x36 0x0 0x44 0x0 0x24 ...            ab
# 3  23.594119  0xAB 0x1 0x0 0x20 0xA8 0x36 0x0 0x44 0x0 0x38 ...            ab
# 4  23.594119  0xAB 0x1 0x0 0x20 0xA9 0x36 0x0 0x44 0x0 0x4B ...            ab
#
#    sender_id  receiver_id  message_id  ...  surface_state  \
# ...
