# %%
# Import neede libraries for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### ***Loading Data for GPS on day 1***

# %%
# load the data
csv_path_1 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\g_data_export_20251110.csv"
df1 = pd.read_csv(csv_path_1)

df1.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  18615026  2025-11-10 01:48:05.187+02    NaN  Aplicom A11 001        499
# 1  18615027   2025-11-10 01:48:07.15+02    NaN  Aplicom A11 001        499
# 2  18615028  2025-11-10 01:48:09.034+02    NaN  Aplicom A11 001        499
# 3  18615033   2025-11-10 01:48:20.72+02    NaN  Aplicom A11 001        499
# 4  18615034  2025-11-10 01:48:23.017+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -86  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...
# 1  E78E9C0B06E0   -79  0201061bff9904050511ffffffff02a4fd14fff87e9655...
# 2  E198DBE2771E   -85  0201061bff9904050530ffffffff03dcfe8cfff074f668...
# 3  E78E9C0B06E0   -81  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...
# 4  E198DBE2771E   -84  0201061bff9904050530ffffffff03dcfe94ffec74f668...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %% [markdown]
# ### ***Loading Data for GPS on day 2***

# %%
csv_path_2 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\g_data_export_20251127.csv"
df2 = pd.read_csv(csv_path_2)
df2.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  19073449  2025-11-27 00:00:05.695+02    NaN  Aplicom A11 001        499
# 1  19073450  2025-11-27 00:02:15.075+02    NaN  Aplicom A11 001        499
# 2  19073451  2025-11-27 00:03:18.962+02    NaN  Aplicom A11 001        499
# 3  19073452   2025-11-27 00:05:26.44+02    NaN  Aplicom A11 001        499
# 4  19073453  2025-11-27 00:06:14.015+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -87  0201061bff990405fbd6ffffffff0274fd18003470f6f6...
# 1  E78E9C0B06E0   -89  0201061bff990405fbcfffffffff022cfd7c00047176e6...
# 2  E78E9C0B06E0   -93  0201061bff990405fbeeffffffff0290fdbcffac71d649...
# 3  E78E9C0B06E0   -89  0201061bff990405fbefffffffff02acfcb4ffd87176f9...
# 4  E78E9C0B06E0   -90  0201061bff990405fbfaffffffff025cfd10fffc70163a...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %% [markdown]
# ### ***Loading Data for GPS on day 3***

# %%
csv_path_3 = r"C:\SUBASH\LAPIN_AMK\SPRING2026\PROJECT\EDA\Hazard_Situation_Analysis_and_Prediction\DATA\g_data_export_20260109.csv"
df3 = pd.read_csv(csv_path_3)
df3.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  20043979  2026-01-09 00:06:10.854+02    NaN  Aplicom A11 001        499
# 1  20043980  2026-01-09 00:06:57.334+02    NaN  Aplicom A11 001        499
# 2  20043981  2026-01-09 00:06:58.861+02    NaN  Aplicom A11 001        499
# 3  20043982  2026-01-09 00:08:24.204+02    NaN  Aplicom A11 001        499
# 4  20044343    2026-01-09 00:09:21.9+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -87  0201061bff990405f37affffffff02c4fd2000086136de...
# 1  E78E9C0B06E0   -89  0201061bff990405f37affffffff02dcfcc0ffc45d362c...
# 2  E78E9C0B06E0   -89  0201061bff990405f378ffffffff02acfd08ffac5d3632...
# 3  E78E9C0B06E0   -88  0201061bff990405f37affffffff02b0fd8c00105f76d7...
# 4  E78E9C0B06E0   -89  0201061bff990405f377ffffffff0260fcb0ffa45d9641...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %% [markdown]
# ### ***Merge 3 DF and making one called "gps_df"***

# %%
# Concatenate the dataframes

gps_df = pd.concat(
    [df1, df2, df3],
    ignore_index=True
)

gps_df.head()
# Out:
#          id                          ts  ruuvi          aplicom  companyid  \
# 0  18615026  2025-11-10 01:48:05.187+02    NaN  Aplicom A11 001        499
# 1  18615027   2025-11-10 01:48:07.15+02    NaN  Aplicom A11 001        499
# 2  18615028  2025-11-10 01:48:09.034+02    NaN  Aplicom A11 001        499
# 3  18615033   2025-11-10 01:48:20.72+02    NaN  Aplicom A11 001        499
# 4  18615034  2025-11-10 01:48:23.017+02    NaN  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -86  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...
# 1  E78E9C0B06E0   -79  0201061bff9904050511ffffffff02a4fd14fff87e9655...
# 2  E198DBE2771E   -85  0201061bff9904050530ffffffff03dcfe8cfff074f668...
# 3  E78E9C0B06E0   -81  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...
# 4  E198DBE2771E   -84  0201061bff9904050530ffffffff03dcfe94ffec74f668...
#
#          lat        lon  ... accx  accy  accz  battvoltage  txpower  \
# ...

# %% [markdown]
# ### ***Shape***

# %%
gps_df.shape
# Out:
# (26277, 22)

# %% [markdown]
# ### ***Describe***

# %%
gps_df.describe()
# Out:
#                  id  ruuvi  companyid          rssi           lat  \
# count  2.627700e+04    0.0    26277.0  26277.000000  26277.000000
# mean   1.913329e+07    NaN      499.0    -87.424782     60.352387
# std    4.615146e+05    NaN        0.0      2.332945      0.145720
# min    1.861503e+07    NaN      499.0    -95.000000     59.819417
# 25%    1.864285e+07    NaN      499.0    -89.000000     60.386161
# 50%    1.908322e+07    NaN      499.0    -88.000000     60.386185
# 75%    1.910004e+07    NaN      499.0    -86.000000     60.445180
# max    2.006978e+07    NaN      499.0    -67.000000     60.502904
#
#                 lon   temperature          accx          accy          accz  \
# count  26277.000000  26277.000000  26277.000000  26277.000000  26277.000000
# mean      22.924812    211.198349    720.812117   -621.705446     -3.796590
# std        0.469647    150.138414    327.647615    239.660314     45.019964
# ...

# %% [markdown]
# ### ***Check for NaN***

# %%
gps_df.isna().sum()
# Out:
# id                     0
# ts                     0
# ruuvi              26277
# aplicom                0
# companyid              0
# address                0
# rssi                   0
# advdata                0
# lat                    0
# lon                    0
# geom                   0
# temperature            0
# accx                   0
# accy                   0
# accz                   0
# battvoltage            0
# txpower                0
# movcounter             0
# measseqnum             0
# calibrated_accx        0
# calibrated_accy        0
# calibrated_accz        0
# dtype: int64

# %% [markdown]
# ### ***lets drop "ruuvi" and see the shape***

# %%
# drop advdata column
gps_df1 = gps_df.drop(columns=['ruuvi'])
gps_df1.shape
# Out:
# (26277, 21)

# %% [markdown]
# ### ***new DF***

# %%
gps_df1.head()
# Out:
#          id                          ts          aplicom  companyid  \
# 0  18615026  2025-11-10 01:48:05.187+02  Aplicom A11 001        499
# 1  18615027   2025-11-10 01:48:07.15+02  Aplicom A11 001        499
# 2  18615028  2025-11-10 01:48:09.034+02  Aplicom A11 001        499
# 3  18615033   2025-11-10 01:48:20.72+02  Aplicom A11 001        499
# 4  18615034  2025-11-10 01:48:23.017+02  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -86  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...
# 1  E78E9C0B06E0   -79  0201061bff9904050511ffffffff02a4fd14fff87e9655...
# 2  E198DBE2771E   -85  0201061bff9904050530ffffffff03dcfe8cfff074f668...
# 3  E78E9C0B06E0   -81  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...
# 4  E198DBE2771E   -84  0201061bff9904050530ffffffff03dcfe94ffec74f668...
#
#          lat        lon                                               geom  \
# ...

# %% [markdown]
# ### ***check for Duplicates***

# %% [markdown]
# No Duplicates

# %%
gps_df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### ***check for DatTypes***

# %%
pd.DataFrame(gps_df1.dtypes, columns=['Data Type'])
# Out:
#                 Data Type
# id                  int64
# ts                    str
# aplicom               str
# companyid           int64
# address               str
# rssi                int64
# advdata               str
# lat               float64
# lon               float64
# geom                  str
# temperature       float64
# accx                int64
# accy                int64
# accz                int64
# battvoltage       float64
# txpower             int64
# movcounter          int64
# measseqnum          int64
# calibrated_accx   float64
# calibrated_accy   float64
# calibrated_accz   float64

# %%
gps_df1.head()
# Out:
#          id                          ts          aplicom  companyid  \
# 0  18615026  2025-11-10 01:48:05.187+02  Aplicom A11 001        499
# 1  18615027   2025-11-10 01:48:07.15+02  Aplicom A11 001        499
# 2  18615028  2025-11-10 01:48:09.034+02  Aplicom A11 001        499
# 3  18615033   2025-11-10 01:48:20.72+02  Aplicom A11 001        499
# 4  18615034  2025-11-10 01:48:23.017+02  Aplicom A11 001        499
#
#         address  rssi                                            advdata  \
# 0  E78E9C0B06E0   -86  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...
# 1  E78E9C0B06E0   -79  0201061bff9904050511ffffffff02a4fd14fff87e9655...
# 2  E198DBE2771E   -85  0201061bff9904050530ffffffff03dcfe8cfff074f668...
# 3  E78E9C0B06E0   -81  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...
# 4  E198DBE2771E   -84  0201061bff9904050530ffffffff03dcfe94ffec74f668...
#
#          lat        lon                                               geom  \
# ...

# %% [markdown]
# ### ***check for features more***

# %%
gps_df1["aplicom"].nunique()
# Out:
# 1

# %%
gps_df1["companyid"].nunique()
# Out:
# 1

# %%
gps_df1["address"].nunique()
# Out:
# 3

# %%
gps_df1["txpower"].nunique()
# Out:
# 2

# %% [markdown]
# ### ***lets remove all features where unique values = 1 for now***

# %%
## REmove aplicom, companyid for now
gps_df2 = gps_df1.drop(columns=['aplicom', 'companyid'])

# %%
gps_df2.head()
# Out:
#          id                          ts       address  rssi  \
# 0  18615026  2025-11-10 01:48:05.187+02  E78E9C0B06E0   -86
# 1  18615027   2025-11-10 01:48:07.15+02  E78E9C0B06E0   -79
# 2  18615028  2025-11-10 01:48:09.034+02  E198DBE2771E   -85
# 3  18615033   2025-11-10 01:48:20.72+02  E78E9C0B06E0   -81
# 4  18615034  2025-11-10 01:48:23.017+02  E198DBE2771E   -84
#
#                                              advdata        lat        lon  \
# 0  0201061bff9904050512ffffffff02a4fd0cfffc7e9655...  60.493215  22.287981
# 1  0201061bff9904050511ffffffff02a4fd14fff87e9655...  60.493212  22.287982
# 2  0201061bff9904050530ffffffff03dcfe8cfff074f668...  60.493206  22.287980
# 3  0201061bff9904050511ffffffff02a0fd0cfffc7e9655...  60.493177  22.288002
# 4  0201061bff9904050530ffffffff03dcfe94ffec74f668...  60.493175  22.288007
#
#                                                 geom  temperature  accx  accy  \
# ...

# %% [markdown]
# ### ***lets remove more unwanted features like transmission pover, battery voltage advertisement payload***

# %%
## REmove battvoltage, advdata, txpower as well
gps_df2 = gps_df2.drop(columns=['battvoltage', 'advdata', 'txpower'])

# %%
gps_df2.head()
# Out:
#          id                          ts       address  rssi        lat  \
# 0  18615026  2025-11-10 01:48:05.187+02  E78E9C0B06E0   -86  60.493215
# 1  18615027   2025-11-10 01:48:07.15+02  E78E9C0B06E0   -79  60.493212
# 2  18615028  2025-11-10 01:48:09.034+02  E198DBE2771E   -85  60.493206
# 3  18615033   2025-11-10 01:48:20.72+02  E78E9C0B06E0   -81  60.493177
# 4  18615034  2025-11-10 01:48:23.017+02  E198DBE2771E   -84  60.493175
#
#          lon                                               geom  temperature  \
# 0  22.287981  0101000020E61000008FDE701FB9493640C5724BAB213F...        6.490
# 1  22.287982  0101000020E610000030D63730B949364054FF2092213F...        6.485
# 2  22.287980  0101000020E6100000EFE6A90EB94936407218CC5F213F...        6.640
# 3  22.288002  0101000020E6100000BE2EC37FBA493640D811876C203F...        6.485
# 4  22.288007  0101000020E6100000E204A6D3BA493640371AC05B203F...        6.640
#
# ...
